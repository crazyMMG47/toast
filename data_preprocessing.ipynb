# %% [markdown]
# # Data Preprocessing Step

# %%
import pandas as pd
from pathlib import Path

df = pd.read_csv('subject_lookup.csv')
mapping = dict(zip(df["OrigCode"], df["SubjectID"]))

# Path to the folder containing subject directories
base_dir = Path("/home/smooi/Desktop/toast/data/toast_pipe_data")  # Change this if needed

# Rename matching folders
for folder in base_dir.iterdir():
    if folder.is_dir() and folder.name in mapping:
        new_name = mapping[folder.name]
        new_path = folder.parent / new_name
        if not new_path.exists():
            print(f"Renaming: {folder.name} → {new_name}")
            folder.rename(new_path)
# Out:
# Renaming: S_aEA_1069A → S016
# Renaming: G_Nemours_0020 → G044
# Renaming: G_2023-U7487-00427-MG → G003
# Renaming: S_Cc_103Pre → S048
# Renaming: S_Cc_MreVolHrsb201 → S062
# Renaming: S_aU01_006 → S044
# Renaming: S_aSTE_005 → S029
# Renaming: G_Nemours_0023 → G047
# Renaming: S_aEA_1049A → S003
# Renaming: S_aEA_1065A → S015
# Renaming: S_MreVol_9 → S072
# Renaming: G_Nemours_0025 → G049
# Renaming: S_MreVol_6 → S069
# Renaming: S_aU01_D2002 → S045
# Renaming: G_Nemours_0001 → G025
# Renaming: S_aU01_004 → S042
# Renaming: G_Nemours_0012 → G036
# Renaming: G_Nemours_0024 → G048
# Renaming: S_aEA_1078B → S023
# Renaming: G_2023-U7487-0719-MS → G015
# Renaming: G_2023-U7487-0706-VP → G014
# Renaming: S_aEA_1076A → S022
# Renaming: G_Nemours_0004 → G028
# Renaming: G_2023-U7778-0188-JG → G022
# Renaming: S_aSTE_018 → S038
# Renaming: G_Nemours_0009 → G033
# Renaming: G_Nemours_0003 → G027
# Renaming: G_2023-U7487-00443-EM → G004
# Renaming: G_2023-U7778-0177-EC → G021
# Renaming: S_Cc_114 → S059
# Renaming: S_aSTE_010 → S034
# Renaming: G_2023-U7487-0736-JM → G018
# Renaming: G_Nemours_0036 → G060
# Renaming: G_2023-U7778-0128-CK → G020
# Renaming: S_aEA_1058A → S011
# Renaming: S_Cc_MreVolHsrb204 → S063
# Renaming: S_MreVol_2 → S066
# Renaming: S_aSTE_016 → S036
# Renaming: G_2023-U7487-0733-DF → G016
# Renaming: S_Cc_104Post → S049
# Renaming: S_aSTE_009 → S033
# Renaming: G_2023-U7487-00641-AZ → G006
# Renaming: S_aEA_1073B → S020
# Renaming: S_aEA_1070A → S017
# Renaming: S_aEA_1057A → S010
# Renaming: S_aEA_1052A → S007
# Renaming: S_Cc_105 → S051
# Renaming: S_aEA_1048A → S002
# Renaming: S_Cc_111 → S056
# Renaming: G_Nemours_0037 → G061
# Renaming: S_aSTE_008 → S032
# Renaming: G_Nemours_0011 → G035
# Renaming: G_2023-U7487-0208-MN → G008
# Renaming: S_Cc_116 → S061
# Renaming: S_Cc_115 → S060
# Renaming: G_Nemours_0029 → G053
# Renaming: S_aSTE_011 → S035
# Renaming: G_Nemours_0028 → G052
# Renaming: G_Nemours_0021 → G045
# Renaming: S_aU01_003 → S041
# Renaming: G_2023-U7487-0613-CT → G010
# Renaming: G_Nemours_0018 → G042
# Renaming: S_MreVol_3 → S067
# Renaming: S_MreVol_1 → S064
# Renaming: G_2023-U7487-00633-ZL → G005
# Renaming: S_Cc_102 → S047
# Renaming: S_aSTE_017 → S037
# Renaming: G_2023-U7778-0209-MK → G023
# Renaming: S_aSTE_002 → S026
# Renaming: S_aEA_1074A → S021
# Renaming: S_Cc_108Pre → S053
# Renaming: G_Nemours_0040 → G063
# Renaming: G_Nemours_0016 → G040
# Renaming: S_MreVol_4 → S068
# Renaming: G_Nemours_0008 → G032
# Renaming: G_Nemours_0039 → G062
# Renaming: S_MreVol_10 → S065
# Renaming: G_Nemours_0005 → G029
# Renaming: G_Nemours_0035 → G059
# Renaming: S_aEA_1055A → S008
# Renaming: S_Cc_112 → S057
# Renaming: S_aEA_1063A → S013
# Renaming: S_aEA_1064A → S014
# Renaming: G_Nemours_0032 → G056
# Renaming: G_Nemours_0014 → G038
# Renaming: S_Cc_106 → S052
# Renaming: S_aEA_1051A → S006
# Renaming: S_aEA_1050B → S005
# Renaming: G_2023-U7778-00112-AL → G019
# Renaming: S_aEA_1072A → S018
# Renaming: G_2023-U7487-0623-AC → G011
# Renaming: S_aEA_1050A → S004
# Renaming: G_Nemours_0017 → G041
# Renaming: G_2023-U7487-0696-GJ → G013
# Renaming: S_aSTE_004 → S028
# Renaming: G_2023-U7487-00676-MK → G007
# Renaming: G_2023-U7487-0632-LK → G012
# Renaming: S_aEA_1079A → S024
# Renaming: G_Nemours_0010 → G034
# Renaming: G_Nemours_0030 → G054
# Renaming: G_ablast_c269 → G024
# Renaming: S_aEA_1046 → S001
# Renaming: S_aEA_1073A → S019
# Renaming: G_2023-U7487-00424-TM → G002
# Renaming: S_aU01_001 → S039
# Renaming: S_aU01_005 → S043
# Renaming: S_aSTE_007 → S031
# Renaming: G_2023-U7487-0734-AJ → G017
# Renaming: S_Cc_104Pre → S050
# Renaming: S_aSTE_001 → S025
# Renaming: S_aU01_002 → S040
# Renaming: G_Nemours_0019 → G043
# Renaming: G_Nemours_0026 → G050
# Renaming: G_Nemours_0007 → G031
# Renaming: G_2023-U7487-00411-NP → G001
# Renaming: G_Nemours_0034 → G058
# Renaming: G_Nemours_0022 → G046
# Renaming: S_MreVol_8 → S071
# Renaming: S_Cc_110 → S055
# Renaming: G_Nemours_0013 → G037
# Renaming: S_aEA_1056A → S009
# Renaming: G_Nemours_0027 → G051
# Renaming: G_2023-U7487-0501-BE → G009
# Renaming: G_Nemours_0033 → G057
# Renaming: S_Cc_101 → S046
# Renaming: G_Nemours_0031 → G055
# Renaming: S_Cc_113 → S058
# Renaming: S_Cc_109 → S054
# Renaming: S_MreVol_7 → S070
# Renaming: S_aSTE_006 → S030
# Renaming: G_Nemours_0002 → G026
# Renaming: G_Nemours_0015 → G039
# Renaming: S_aEA_1062A → S012
# Renaming: G_Nemours_0006 → G030
# Renaming: S_aSTE_003 → S027

# %%
from pathlib import Path

def rename_files_by_subject_id(root_dir):
    root = Path(root_dir)
    for subject_folder in root.iterdir():
        if subject_folder.is_dir():
            subject_id = subject_folder.name
            for file in subject_folder.iterdir():
                if file.is_file():
                    new_name = f"{subject_id}_{file.name}"
                    new_path = file.parent / new_name
                    file.rename(new_path)
                    print(f"Renamed: {file.name} → {new_name}")

# Example usage
rename_files_by_subject_id("/home/smooi/Desktop/toast/data/toast_pipe_data")   # e.g., "toast_pipe_data"
# Out:
# Renamed: t2bet.nii → G041_t2bet.nii
# Renamed: stiff_prob.mat → G041_stiff_prob.mat
# Renamed: mask.mat → G041_mask.mat
# Renamed: t2stack.nii → G041_t2stack.nii
# Renamed: t2stack.mat → G041_t2stack.mat
# Renamed: Mu.mat → G041_Mu.mat
# Renamed: t2bet_norm.nii → G041_t2bet_norm.nii
# Renamed: t2bet.nii → G053_t2bet.nii
# Renamed: stiff_prob.mat → G053_stiff_prob.mat
# Renamed: mask.mat → G053_mask.mat
# Renamed: t2stack.nii → G053_t2stack.nii
# Renamed: t2stack.mat → G053_t2stack.mat
# Renamed: Mu.mat → G053_Mu.mat
# Renamed: t2bet_norm.nii → G053_t2bet_norm.nii
# Renamed: t2bet.nii → G014_t2bet.nii
# Renamed: stiff_prob.mat → G014_stiff_prob.mat
# Renamed: mask.mat → G014_mask.mat
# Renamed: t2stack.nii → G014_t2stack.nii
# Renamed: t2stack.mat → G014_t2stack.mat
# Renamed: Mu.mat → G014_Mu.mat
# Renamed: t2bet_norm.nii → G014_t2bet_norm.nii
# Renamed: t2bet.nii → G047_t2bet.nii
# Renamed: stiff_prob.mat → G047_stiff_prob.mat
# Renamed: mask.mat → G047_mask.mat
# Renamed: t2stack.nii → G047_t2stack.nii
# Renamed: t2stack.mat → G047_t2stack.mat
# Renamed: Mu.mat → G047_Mu.mat
# Renamed: t2bet_norm.nii → G047_t2bet_norm.nii
# Renamed: t2bet.nii → S023_t2bet.nii
# Renamed: stiff_prob.mat → S023_stiff_prob.mat
# Renamed: mask.mat → S023_mask.mat
# Renamed: t2stack.nii → S023_t2stack.nii
# Renamed: t2stack.mat → S023_t2stack.mat
# Renamed: Mu.mat → S023_Mu.mat
# Renamed: t2bet_norm.nii → S023_t2bet_norm.nii
# Renamed: t2bet.nii → S043_t2bet.nii
# Renamed: stiff_prob.mat → S043_stiff_prob.mat
# Renamed: mask.mat → S043_mask.mat
# Renamed: t2stack.nii → S043_t2stack.nii
# Renamed: t2stack.mat → S043_t2stack.mat
# Renamed: Mu.mat → S043_Mu.mat
# Renamed: t2bet_norm.nii → S043_t2bet_norm.nii
# Renamed: t2bet.nii → S030_t2bet.nii
# Renamed: stiff_prob.mat → S030_stiff_prob.mat
# Renamed: mask.mat → S030_mask.mat
# Renamed: t2stack.nii → S030_t2stack.nii
# Renamed: t2stack.mat → S030_t2stack.mat
# Renamed: Mu.mat → S030_Mu.mat
# Renamed: t2bet_norm.nii → S030_t2bet_norm.nii
# Renamed: t2bet.nii → G011_t2bet.nii
# Renamed: stiff_prob.mat → G011_stiff_prob.mat
# Renamed: mask.mat → G011_mask.mat
# Renamed: t2stack.nii → G011_t2stack.nii
# Renamed: t2stack.mat → G011_t2stack.mat
# Renamed: Mu.mat → G011_Mu.mat
# Renamed: t2bet_norm.nii → G011_t2bet_norm.nii
# Renamed: t2bet.nii → S015_t2bet.nii
# Renamed: stiff_prob.mat → S015_stiff_prob.mat
# Renamed: mask.mat → S015_mask.mat
# Renamed: t2stack.nii → S015_t2stack.nii
# Renamed: t2stack.mat → S015_t2stack.mat
# Renamed: Mu.mat → S015_Mu.mat
# Renamed: t2bet_norm.nii → S015_t2bet_norm.nii
# Renamed: t2bet.nii → G037_t2bet.nii
# Renamed: stiff_prob.mat → G037_stiff_prob.mat
# Renamed: mask.mat → G037_mask.mat
# Renamed: t2stack.nii → G037_t2stack.nii
# Renamed: t2stack.mat → G037_t2stack.mat
# Renamed: Mu.mat → G037_Mu.mat
# Renamed: t2bet_norm.nii → G037_t2bet_norm.nii
# Renamed: t2bet.nii → S070_t2bet.nii
# Renamed: stiff_prob.mat → S070_stiff_prob.mat
# Renamed: mask.mat → S070_mask.mat
# Renamed: t2stack.nii → S070_t2stack.nii
# Renamed: t2stack.mat → S070_t2stack.mat
# Renamed: Mu.mat → S070_Mu.mat
# Renamed: t2bet_norm.nii → S070_t2bet_norm.nii
# Renamed: t2bet.nii → S011_t2bet.nii
# Renamed: stiff_prob.mat → S011_stiff_prob.mat
# Renamed: mask.mat → S011_mask.mat
# Renamed: t2stack.nii → S011_t2stack.nii
# Renamed: t2stack.mat → S011_t2stack.mat
# Renamed: Mu.mat → S011_Mu.mat
# Renamed: t2bet_norm.nii → S011_t2bet_norm.nii
# Renamed: t2bet.nii → S044_t2bet.nii
# Renamed: stiff_prob.mat → S044_stiff_prob.mat
# Renamed: mask.mat → S044_mask.mat
# Renamed: t2stack.nii → S044_t2stack.nii
# Renamed: t2stack.mat → S044_t2stack.mat
# Renamed: Mu.mat → S044_Mu.mat
# Renamed: t2bet_norm.nii → S044_t2bet_norm.nii
# Renamed: t2bet.nii → G021_t2bet.nii
# Renamed: stiff_prob.mat → G021_stiff_prob.mat
# Renamed: mask.mat → G021_mask.mat
# Renamed: t2mask_final.mat → G021_t2mask_final.mat
# Renamed: t2stack.nii → G021_t2stack.nii
# Renamed: t2stack.mat → G021_t2stack.mat
# Renamed: Mu.mat → G021_Mu.mat
# Renamed: t2bet_norm.nii → G021_t2bet_norm.nii
# Renamed: t2bet.nii → S045_t2bet.nii
# Renamed: stiff_prob.mat → S045_stiff_prob.mat
# Renamed: mask.mat → S045_mask.mat
# Renamed: t2stack.nii → S045_t2stack.nii
# Renamed: t2stack.mat → S045_t2stack.mat
# Renamed: Mu.mat → S045_Mu.mat
# Renamed: t2bet_norm.nii → S045_t2bet_norm.nii
# Renamed: t2bet.nii → G029_t2bet.nii
# Renamed: stiff_prob.mat → G029_stiff_prob.mat
# Renamed: mask.mat → G029_mask.mat
# Renamed: t2stack.nii → G029_t2stack.nii
# Renamed: t2stack.mat → G029_t2stack.mat
# Renamed: Mu.mat → G029_Mu.mat
# Renamed: t2bet_norm.nii → G029_t2bet_norm.nii
# Renamed: t2bet.nii → S031_t2bet.nii
# Renamed: stiff_prob.mat → S031_stiff_prob.mat
# Renamed: mask.mat → S031_mask.mat
# Renamed: t2stack.nii → S031_t2stack.nii
# Renamed: t2stack.mat → S031_t2stack.mat
# Renamed: Mu.mat → S031_Mu.mat
# Renamed: t2bet_norm.nii → S031_t2bet_norm.nii
# Renamed: t2bet.nii → G028_t2bet.nii
# Renamed: stiff_prob.mat → G028_stiff_prob.mat
# Renamed: mask.mat → G028_mask.mat
# Renamed: t2stack.nii → G028_t2stack.nii
# Renamed: t2stack.mat → G028_t2stack.mat
# Renamed: Mu.mat → G028_Mu.mat
# Renamed: t2bet_norm.nii → G028_t2bet_norm.nii
# Renamed: t2bet.nii → G044_t2bet.nii
# Renamed: stiff_prob.mat → G044_stiff_prob.mat
# Renamed: mask.mat → G044_mask.mat
# Renamed: t2stack.nii → G044_t2stack.nii
# Renamed: t2stack.mat → G044_t2stack.mat
# Renamed: Mu.mat → G044_Mu.mat
# Renamed: t2bet_norm.nii → G044_t2bet_norm.nii
# Renamed: t2bet.nii → G022_t2bet.nii
# Renamed: stiff_prob.mat → G022_stiff_prob.mat
# Renamed: mask.mat → G022_mask.mat
# Renamed: t2mask_final.mat → G022_t2mask_final.mat
# Renamed: t2stack.nii → G022_t2stack.nii
# Renamed: t2stack.mat → G022_t2stack.mat
# Renamed: Mu.mat → G022_Mu.mat
# Renamed: t2bet_norm.nii → G022_t2bet_norm.nii
# Renamed: t2bet.nii → S042_t2bet.nii
# Renamed: stiff_prob.mat → S042_stiff_prob.mat
# Renamed: mask.mat → S042_mask.mat
# Renamed: t2stack.nii → S042_t2stack.nii
# Renamed: t2stack.mat → S042_t2stack.mat
# Renamed: Mu.mat → S042_Mu.mat
# Renamed: t2bet_norm.nii → S042_t2bet_norm.nii
# Renamed: t2bet.nii → G046_t2bet.nii
# Renamed: stiff_prob.mat → G046_stiff_prob.mat
# Renamed: mask.mat → G046_mask.mat
# Renamed: t2stack.nii → G046_t2stack.nii
# Renamed: t2stack.mat → G046_t2stack.mat
# Renamed: Mu.mat → G046_Mu.mat
# Renamed: t2bet_norm.nii → G046_t2bet_norm.nii
# Renamed: t2bet.nii → G007_t2bet.nii
# Renamed: stiff_prob.mat → G007_stiff_prob.mat
# Renamed: mask.mat → G007_mask.mat
# Renamed: t2stack.nii → G007_t2stack.nii
# Renamed: t2stack.mat → G007_t2stack.mat
# Renamed: Mu.mat → G007_Mu.mat
# Renamed: t2bet_norm.nii → G007_t2bet_norm.nii
# Renamed: t2bet.nii → G025_t2bet.nii
# Renamed: stiff_prob.mat → G025_stiff_prob.mat
# Renamed: mask.mat → G025_mask.mat
# Renamed: t2stack.nii → G025_t2stack.nii
# Renamed: t2stack.mat → G025_t2stack.mat
# Renamed: Mu.mat → G025_Mu.mat
# Renamed: t2bet_norm.nii → G025_t2bet_norm.nii
# Renamed: t2bet.nii → G060_t2bet.nii
# Renamed: stiff_prob.mat → G060_stiff_prob.mat
# Renamed: mask.mat → G060_mask.mat
# Renamed: t2stack.nii → G060_t2stack.nii
# Renamed: t2stack.mat → G060_t2stack.mat
# Renamed: Mu.mat → G060_Mu.mat
# Renamed: t2bet_norm.nii → G060_t2bet_norm.nii
# Renamed: t2bet.nii → S012_t2bet.nii
# Renamed: stiff_prob.mat → S012_stiff_prob.mat
# Renamed: mask.mat → S012_mask.mat
# Renamed: t2stack.nii → S012_t2stack.nii
# Renamed: t2stack.mat → S012_t2stack.mat
# Renamed: Mu.mat → S012_Mu.mat
# Renamed: t2bet_norm.nii → S012_t2bet_norm.nii
# Renamed: t2bet.nii → S018_t2bet.nii
# Renamed: stiff_prob.mat → S018_stiff_prob.mat
# Renamed: mask.mat → S018_mask.mat
# Renamed: t2stack.nii → S018_t2stack.nii
# Renamed: t2stack.mat → S018_t2stack.mat
# Renamed: Mu.mat → S018_Mu.mat
# Renamed: t2bet_norm.nii → S018_t2bet_norm.nii
# Renamed: t2bet.nii → G035_t2bet.nii
# Renamed: stiff_prob.mat → G035_stiff_prob.mat
# Renamed: mask.mat → G035_mask.mat
# Renamed: t2stack.nii → G035_t2stack.nii
# Renamed: t2stack.mat → G035_t2stack.mat
# Renamed: Mu.mat → G035_Mu.mat
# Renamed: t2bet_norm.nii → G035_t2bet_norm.nii
# Renamed: t2bet.nii → S055_t2bet.nii
# Renamed: stiff_prob.mat → S055_stiff_prob.mat
# Renamed: mask.mat → S055_mask.mat
# Renamed: t2stack.nii → S055_t2stack.nii
# Renamed: t2stack.mat → S055_t2stack.mat
# Renamed: Mu.mat → S055_Mu.mat
# Renamed: t2bet_norm.nii → S055_t2bet_norm.nii
# Renamed: t2bet.nii → G033_t2bet.nii
# Renamed: stiff_prob.mat → G033_stiff_prob.mat
# Renamed: mask.mat → G033_mask.mat
# Renamed: t2stack.nii → G033_t2stack.nii
# Renamed: t2stack.mat → G033_t2stack.mat
# Renamed: Mu.mat → G033_Mu.mat
# Renamed: t2bet_norm.nii → G033_t2bet_norm.nii
# Renamed: t2bet.nii → G051_t2bet.nii
# Renamed: stiff_prob.mat → G051_stiff_prob.mat
# Renamed: mask.mat → G051_mask.mat
# Renamed: t2stack.nii → G051_t2stack.nii
# Renamed: t2stack.mat → G051_t2stack.mat
# Renamed: Mu.mat → G051_Mu.mat
# Renamed: t2bet_norm.nii → G051_t2bet_norm.nii
# Renamed: t2bet.nii → S067_t2bet.nii
# Renamed: stiff_prob.mat → S067_stiff_prob.mat
# Renamed: mask.mat → S067_mask.mat
# Renamed: t2stack.nii → S067_t2stack.nii
# Renamed: t2stack.mat → S067_t2stack.mat
# Renamed: Mu.mat → S067_Mu.mat
# Renamed: t2bet_norm.nii → S067_t2bet_norm.nii
# Renamed: t2bet.nii → G015_t2bet.nii
# Renamed: stiff_prob.mat → G015_stiff_prob.mat
# Renamed: mask.mat → G015_mask.mat
# Renamed: t2stack.nii → G015_t2stack.nii
# Renamed: t2stack.mat → G015_t2stack.mat
# Renamed: Mu.mat → G015_Mu.mat
# Renamed: t2bet_norm.nii → G015_t2bet_norm.nii
# Renamed: t2bet.nii → G049_t2bet.nii
# Renamed: stiff_prob.mat → G049_stiff_prob.mat
# Renamed: mask.mat → G049_mask.mat
# Renamed: t2stack.nii → G049_t2stack.nii
# Renamed: t2stack.mat → G049_t2stack.mat
# Renamed: Mu.mat → G049_Mu.mat
# Renamed: t2bet_norm.nii → G049_t2bet_norm.nii
# Renamed: t2bet.nii → G030_t2bet.nii
# Renamed: stiff_prob.mat → G030_stiff_prob.mat
# Renamed: mask.mat → G030_mask.mat
# Renamed: t2stack.nii → G030_t2stack.nii
# Renamed: t2stack.mat → G030_t2stack.mat
# Renamed: Mu.mat → G030_Mu.mat
# Renamed: t2bet_norm.nii → G030_t2bet_norm.nii
# Renamed: t2bet.nii → S032_t2bet.nii
# Renamed: stiff_prob.mat → S032_stiff_prob.mat
# Renamed: mask.mat → S032_mask.mat
# Renamed: t2stack.nii → S032_t2stack.nii
# Renamed: t2stack.mat → S032_t2stack.mat
# Renamed: Mu.mat → S032_Mu.mat
# Renamed: t2bet_norm.nii → S032_t2bet_norm.nii
# Renamed: t2bet.nii → G050_t2bet.nii
# Renamed: stiff_prob.mat → G050_stiff_prob.mat
# Renamed: mask.mat → G050_mask.mat
# Renamed: t2stack.nii → G050_t2stack.nii
# Renamed: t2stack.mat → G050_t2stack.mat
# Renamed: Mu.mat → G050_Mu.mat
# Renamed: t2bet_norm.nii → G050_t2bet_norm.nii
# Renamed: t2bet.nii → G012_t2bet.nii
# Renamed: stiff_prob.mat → G012_stiff_prob.mat
# Renamed: mask.mat → G012_mask.mat
# Renamed: t2stack.nii → G012_t2stack.nii
# Renamed: t2stack.mat → G012_t2stack.mat
# Renamed: Mu.mat → G012_Mu.mat
# Renamed: t2bet_norm.nii → G012_t2bet_norm.nii
# Renamed: t2bet.nii → G001_t2bet.nii
# Renamed: stiff_prob.mat → G001_stiff_prob.mat
# Renamed: mask.mat → G001_mask.mat
# Renamed: t2stack.nii → G001_t2stack.nii
# Renamed: t2stack.mat → G001_t2stack.mat
# Renamed: Mu.mat → G001_Mu.mat
# Renamed: t2bet_norm.nii → G001_t2bet_norm.nii
# Renamed: t2bet.nii → S049_t2bet.nii
# Renamed: stiff_prob.mat → S049_stiff_prob.mat
# Renamed: mask.mat → S049_mask.mat
# Renamed: t2stack.nii → S049_t2stack.nii
# Renamed: t2stack.mat → S049_t2stack.mat
# Renamed: Mu.mat → S049_Mu.mat
# Renamed: t2bet_norm.nii → S049_t2bet_norm.nii
# Renamed: t2bet.nii → S068_t2bet.nii
# Renamed: stiff_prob.mat → S068_stiff_prob.mat
# Renamed: mask.mat → S068_mask.mat
# Renamed: t2stack.nii → S068_t2stack.nii
# Renamed: t2stack.mat → S068_t2stack.mat
# Renamed: Mu.mat → S068_Mu.mat
# Renamed: t2bet_norm.nii → S068_t2bet_norm.nii
# Renamed: t2bet.nii → S046_t2bet.nii
# Renamed: stiff_prob.mat → S046_stiff_prob.mat
# Renamed: mask.mat → S046_mask.mat
# Renamed: t2stack.nii → S046_t2stack.nii
# Renamed: t2stack.mat → S046_t2stack.mat
# Renamed: Mu.mat → S046_Mu.mat
# Renamed: t2bet_norm.nii → S046_t2bet_norm.nii
# Renamed: t2bet.nii → G031_t2bet.nii
# Renamed: stiff_prob.mat → G031_stiff_prob.mat
# Renamed: mask.mat → G031_mask.mat
# Renamed: t2stack.nii → G031_t2stack.nii
# Renamed: t2stack.mat → G031_t2stack.mat
# Renamed: Mu.mat → G031_Mu.mat
# Renamed: t2bet_norm.nii → G031_t2bet_norm.nii
# Renamed: t2bet.nii → G055_t2bet.nii
# Renamed: stiff_prob.mat → G055_stiff_prob.mat
# Renamed: mask.mat → G055_mask.mat
# Renamed: t2stack.nii → G055_t2stack.nii
# Renamed: t2stack.mat → G055_t2stack.mat
# Renamed: Mu.mat → G055_Mu.mat
# Renamed: t2bet_norm.nii → G055_t2bet_norm.nii
# Renamed: t2bet.nii → G006_t2bet.nii
# Renamed: stiff_prob.mat → G006_stiff_prob.mat
# Renamed: mask.mat → G006_mask.mat
# Renamed: t2stack.nii → G006_t2stack.nii
# Renamed: t2stack.mat → G006_t2stack.mat
# Renamed: Mu.mat → G006_Mu.mat
# Renamed: t2bet_norm.nii → G006_t2bet_norm.nii
# Renamed: t2bet.nii → G034_t2bet.nii
# Renamed: stiff_prob.mat → G034_stiff_prob.mat
# Renamed: mask.mat → G034_mask.mat
# Renamed: t2stack.nii → G034_t2stack.nii
# Renamed: t2stack.mat → G034_t2stack.mat
# Renamed: Mu.mat → G034_Mu.mat
# Renamed: t2bet_norm.nii → G034_t2bet_norm.nii
# Renamed: t2bet.nii → S051_t2bet.nii
# Renamed: stiff_prob.mat → S051_stiff_prob.mat
# Renamed: mask.mat → S051_mask.mat
# Renamed: t2stack.nii → S051_t2stack.nii
# Renamed: t2stack.mat → S051_t2stack.mat
# Renamed: Mu.mat → S051_Mu.mat
# Renamed: t2bet_norm.nii → S051_t2bet_norm.nii
# Renamed: t2bet.nii → G004_t2bet.nii
# Renamed: stiff_prob.mat → G004_stiff_prob.mat
# Renamed: mask.mat → G004_mask.mat
# Renamed: t2stack.nii → G004_t2stack.nii
# Renamed: t2stack.mat → G004_t2stack.mat
# Renamed: Mu.mat → G004_Mu.mat
# Renamed: t2bet_norm.nii → G004_t2bet_norm.nii
# Renamed: t2bet.nii → S040_t2bet.nii
# Renamed: stiff_prob.mat → S040_stiff_prob.mat
# Renamed: mask.mat → S040_mask.mat
# Renamed: t2stack.nii → S040_t2stack.nii
# Renamed: t2stack.mat → S040_t2stack.mat
# Renamed: Mu.mat → S040_Mu.mat
# Renamed: t2bet_norm.nii → S040_t2bet_norm.nii
# Renamed: t2bet.nii → S008_t2bet.nii
# Renamed: stiff_prob.mat → S008_stiff_prob.mat
# Renamed: mask.mat → S008_mask.mat
# Renamed: t2stack.nii → S008_t2stack.nii
# Renamed: t2stack.mat → S008_t2stack.mat
# Renamed: Mu.mat → S008_Mu.mat
# Renamed: t2bet_norm.nii → S008_t2bet_norm.nii
# Renamed: t2bet.nii → S035_t2bet.nii
# Renamed: stiff_prob.mat → S035_stiff_prob.mat
# Renamed: mask.mat → S035_mask.mat
# Renamed: t2stack.nii → S035_t2stack.nii
# Renamed: t2stack.mat → S035_t2stack.mat
# Renamed: Mu.mat → S035_Mu.mat
# Renamed: t2bet_norm.nii → S035_t2bet_norm.nii
# Renamed: t2bet.nii → S062_t2bet.nii
# Renamed: stiff_prob.mat → S062_stiff_prob.mat
# Renamed: mask.mat → S062_mask.mat
# Renamed: t2stack.nii → S062_t2stack.nii
# Renamed: t2stack.mat → S062_t2stack.mat
# Renamed: Mu.mat → S062_Mu.mat
# Renamed: t2bet_norm.nii → S062_t2bet_norm.nii
# Renamed: t2bet.nii → G039_t2bet.nii
# Renamed: stiff_prob.mat → G039_stiff_prob.mat
# Renamed: mask.mat → G039_mask.mat
# Renamed: t2stack.nii → G039_t2stack.nii
# Renamed: t2stack.mat → G039_t2stack.mat
# Renamed: Mu.mat → G039_Mu.mat
# Renamed: t2bet_norm.nii → G039_t2bet_norm.nii
# Renamed: t2bet.nii → S041_t2bet.nii
# Renamed: stiff_prob.mat → S041_stiff_prob.mat
# Renamed: mask.mat → S041_mask.mat
# Renamed: t2stack.nii → S041_t2stack.nii
# Renamed: t2stack.mat → S041_t2stack.mat
# Renamed: Mu.mat → S041_Mu.mat
# Renamed: t2bet_norm.nii → S041_t2bet_norm.nii
# Renamed: t2bet.nii → S029_t2bet.nii
# Renamed: stiff_prob.mat → S029_stiff_prob.mat
# Renamed: mask.mat → S029_mask.mat
# Renamed: t2stack.nii → S029_t2stack.nii
# Renamed: t2stack.mat → S029_t2stack.mat
# Renamed: Mu.mat → S029_Mu.mat
# Renamed: t2bet_norm.nii → S029_t2bet_norm.nii
# Renamed: t2bet.nii → G005_t2bet.nii
# Renamed: stiff_prob.mat → G005_stiff_prob.mat
# Renamed: mask.mat → G005_mask.mat
# Renamed: t2stack.nii → G005_t2stack.nii
# Renamed: t2stack.mat → G005_t2stack.mat
# Renamed: Mu.mat → G005_Mu.mat
# Renamed: t2bet_norm.nii → G005_t2bet_norm.nii
# Renamed: t2bet.nii → S033_t2bet.nii
# Renamed: stiff_prob.mat → S033_stiff_prob.mat
# Renamed: mask.mat → S033_mask.mat
# Renamed: t2stack.nii → S033_t2stack.nii
# Renamed: t2stack.mat → S033_t2stack.mat
# Renamed: Mu.mat → S033_Mu.mat
# Renamed: t2bet_norm.nii → S033_t2bet_norm.nii
# Renamed: t2bet.nii → G013_t2bet.nii
# Renamed: stiff_prob.mat → G013_stiff_prob.mat
# Renamed: mask.mat → G013_mask.mat
# Renamed: t2stack.nii → G013_t2stack.nii
# Renamed: t2stack.mat → G013_t2stack.mat
# Renamed: Mu.mat → G013_Mu.mat
# Renamed: t2bet_norm.nii → G013_t2bet_norm.nii
# Renamed: t2bet.nii → G020_t2bet.nii
# Renamed: stiff_prob.mat → G020_stiff_prob.mat
# Renamed: mask.mat → G020_mask.mat
# Renamed: t2mask_final.mat → G020_t2mask_final.mat
# Renamed: t2stack.nii → G020_t2stack.nii
# Renamed: t2stack.mat → G020_t2stack.mat
# Renamed: Mu.mat → G020_Mu.mat
# Renamed: t2bet_norm.nii → G020_t2bet_norm.nii
# Renamed: t2bet.nii → G003_t2bet.nii
# Renamed: stiff_prob.mat → G003_stiff_prob.mat
# Renamed: mask.mat → G003_mask.mat
# Renamed: t2stack.nii → G003_t2stack.nii
# Renamed: t2stack.mat → G003_t2stack.mat
# Renamed: Mu.mat → G003_Mu.mat
# Renamed: t2bet_norm.nii → G003_t2bet_norm.nii
# Renamed: t2bet.nii → S007_t2bet.nii
# Renamed: stiff_prob.mat → S007_stiff_prob.mat
# Renamed: mask.mat → S007_mask.mat
# Renamed: t2stack.nii → S007_t2stack.nii
# Renamed: t2stack.mat → S007_t2stack.mat
# Renamed: Mu.mat → S007_Mu.mat
# Renamed: t2bet_norm.nii → S007_t2bet_norm.nii
# Renamed: t2bet.nii → S059_t2bet.nii
# Renamed: stiff_prob.mat → S059_stiff_prob.mat
# Renamed: mask.mat → S059_mask.mat
# Renamed: t2stack.nii → S059_t2stack.nii
# Renamed: t2stack.mat → S059_t2stack.mat
# Renamed: Mu.mat → S059_Mu.mat
# Renamed: t2bet_norm.nii → S059_t2bet_norm.nii
# Renamed: t2bet.nii → S001_t2bet.nii
# Renamed: stiff_prob.mat → S001_stiff_prob.mat
# Renamed: mask.mat → S001_mask.mat
# Renamed: .DS_Store → S001_.DS_Store
# Renamed: t2stack.nii → S001_t2stack.nii
# Renamed: t2stack.mat → S001_t2stack.mat
# Renamed: Mu.mat → S001_Mu.mat
# Renamed: t2bet_norm.nii → S001_t2bet_norm.nii
# Renamed: t2bet.nii → G009_t2bet.nii
# Renamed: stiff_prob.mat → G009_stiff_prob.mat
# Renamed: mask.mat → G009_mask.mat
# Renamed: t2stack.nii → G009_t2stack.nii
# Renamed: t2stack.mat → G009_t2stack.mat
# Renamed: Mu.mat → G009_Mu.mat
# Renamed: t2bet_norm.nii → G009_t2bet_norm.nii
# Renamed: t2bet.nii → G062_t2bet.nii
# Renamed: stiff_prob.mat → G062_stiff_prob.mat
# Renamed: mask.mat → G062_mask.mat
# Renamed: t2stack.nii → G062_t2stack.nii
# Renamed: t2stack.mat → G062_t2stack.mat
# Renamed: Mu.mat → G062_Mu.mat
# Renamed: t2bet_norm.nii → G062_t2bet_norm.nii
# Renamed: t2bet.nii → S002_t2bet.nii
# Renamed: stiff_prob.mat → S002_stiff_prob.mat
# Renamed: mask.mat → S002_mask.mat
# Renamed: t2stack.nii → S002_t2stack.nii
# Renamed: t2stack.mat → S002_t2stack.mat
# Renamed: Mu.mat → S002_Mu.mat
# Renamed: t2bet_norm.nii → S002_t2bet_norm.nii
# Renamed: t2bet.nii → S003_t2bet.nii
# Renamed: stiff_prob.mat → S003_stiff_prob.mat
# Renamed: mask.mat → S003_mask.mat
# Renamed: t2stack.nii → S003_t2stack.nii
# Renamed: t2stack.mat → S003_t2stack.mat
# Renamed: Mu.mat → S003_Mu.mat
# Renamed: t2bet_norm.nii → S003_t2bet_norm.nii
# Renamed: t2bet.nii → G057_t2bet.nii
# Renamed: stiff_prob.mat → G057_stiff_prob.mat
# Renamed: mask.mat → G057_mask.mat
# Renamed: t2stack.nii → G057_t2stack.nii
# Renamed: t2stack.mat → G057_t2stack.mat
# Renamed: Mu.mat → G057_Mu.mat
# Renamed: t2bet_norm.nii → G057_t2bet_norm.nii
# Renamed: t2bet.nii → S019_t2bet.nii
# Renamed: stiff_prob.mat → S019_stiff_prob.mat
# Renamed: mask.mat → S019_mask.mat
# Renamed: t2stack.nii → S019_t2stack.nii
# Renamed: t2stack.mat → S019_t2stack.mat
# Renamed: Mu.mat → S019_Mu.mat
# Renamed: t2bet_norm.nii → S019_t2bet_norm.nii
# Renamed: t2bet.nii → S017_t2bet.nii
# Renamed: stiff_prob.mat → S017_stiff_prob.mat
# Renamed: mask.mat → S017_mask.mat
# Renamed: t2stack.nii → S017_t2stack.nii
# Renamed: t2stack.mat → S017_t2stack.mat
# Renamed: Mu.mat → S017_Mu.mat
# Renamed: t2bet_norm.nii → S017_t2bet_norm.nii
# Renamed: t2bet.nii → S024_t2bet.nii
# Renamed: stiff_prob.mat → S024_stiff_prob.mat
# Renamed: mask.mat → S024_mask.mat
# Renamed: t2stack.nii → S024_t2stack.nii
# Renamed: t2stack.mat → S024_t2stack.mat
# Renamed: Mu.mat → S024_Mu.mat
# Renamed: t2bet_norm.nii → S024_t2bet_norm.nii
# Renamed: t2bet.nii → S058_t2bet.nii
# Renamed: stiff_prob.mat → S058_stiff_prob.mat
# Renamed: mask.mat → S058_mask.mat
# Renamed: t2stack.nii → S058_t2stack.nii
# Renamed: t2stack.mat → S058_t2stack.mat
# Renamed: Mu.mat → S058_Mu.mat
# Renamed: t2bet_norm.nii → S058_t2bet_norm.nii
# Renamed: t2bet.nii → S005_t2bet.nii
# Renamed: stiff_prob.mat → S005_stiff_prob.mat
# Renamed: mask.mat → S005_mask.mat
# Renamed: t2stack.nii → S005_t2stack.nii
# Renamed: t2stack.mat → S005_t2stack.mat
# Renamed: Mu.mat → S005_Mu.mat
# Renamed: t2bet_norm.nii → S005_t2bet_norm.nii
# Renamed: t2bet.nii → S016_t2bet.nii
# Renamed: stiff_prob.mat → S016_stiff_prob.mat
# Renamed: mask.mat → S016_mask.mat
# Renamed: t2stack.nii → S016_t2stack.nii
# Renamed: t2stack.mat → S016_t2stack.mat
# Renamed: Mu.mat → S016_Mu.mat
# Renamed: t2bet_norm.nii → S016_t2bet_norm.nii
# Renamed: t2bet.nii → G063_t2bet.nii
# Renamed: stiff_prob.mat → G063_stiff_prob.mat
# Renamed: mask.mat → G063_mask.mat
# Renamed: t2stack.nii → G063_t2stack.nii
# Renamed: t2stack.mat → G063_t2stack.mat
# Renamed: Mu.mat → G063_Mu.mat
# Renamed: t2bet_norm.nii → G063_t2bet_norm.nii
# Renamed: t2bet.nii → S072_t2bet.nii
# Renamed: stiff_prob.mat → S072_stiff_prob.mat
# Renamed: mask.mat → S072_mask.mat
# Renamed: t2stack.nii → S072_t2stack.nii
# Renamed: t2stack.mat → S072_t2stack.mat
# Renamed: Mu.mat → S072_Mu.mat
# Renamed: t2bet_norm.nii → S072_t2bet_norm.nii
# Renamed: t2bet.nii → S060_t2bet.nii
# Renamed: stiff_prob.mat → S060_stiff_prob.mat
# Renamed: mask.mat → S060_mask.mat
# Renamed: t2stack.nii → S060_t2stack.nii
# Renamed: t2stack.mat → S060_t2stack.mat
# Renamed: Mu.mat → S060_Mu.mat
# Renamed: t2bet_norm.nii → S060_t2bet_norm.nii
# Renamed: t2bet.nii → S004_t2bet.nii
# Renamed: stiff_prob.mat → S004_stiff_prob.mat
# Renamed: mask.mat → S004_mask.mat
# Renamed: t2stack.nii → S004_t2stack.nii
# Renamed: t2stack.mat → S004_t2stack.mat
# Renamed: Mu.mat → S004_Mu.mat
# Renamed: t2bet_norm.nii → S004_t2bet_norm.nii
# Renamed: t2bet.nii → S069_t2bet.nii
# Renamed: stiff_prob.mat → S069_stiff_prob.mat
# Renamed: mask.mat → S069_mask.mat
# Renamed: t2stack.nii → S069_t2stack.nii
# Renamed: t2stack.mat → S069_t2stack.mat
# Renamed: Mu.mat → S069_Mu.mat
# Renamed: t2bet_norm.nii → S069_t2bet_norm.nii
# Renamed: t2bet.nii → S009_t2bet.nii
# Renamed: stiff_prob.mat → S009_stiff_prob.mat
# Renamed: mask.mat → S009_mask.mat
# Renamed: t2stack.nii → S009_t2stack.nii
# Renamed: t2stack.mat → S009_t2stack.mat
# Renamed: Mu.mat → S009_Mu.mat
# Renamed: t2bet_norm.nii → S009_t2bet_norm.nii
# Renamed: t2bet.nii → S048_t2bet.nii
# Renamed: stiff_prob.mat → S048_stiff_prob.mat
# Renamed: mask.mat → S048_mask.mat
# Renamed: t2stack.nii → S048_t2stack.nii
# Renamed: t2stack.mat → S048_t2stack.mat
# Renamed: Mu.mat → S048_Mu.mat
# Renamed: t2bet_norm.nii → S048_t2bet_norm.nii
# Renamed: t2bet.nii → S013_t2bet.nii
# Renamed: stiff_prob.mat → S013_stiff_prob.mat
# Renamed: mask.mat → S013_mask.mat
# Renamed: t2stack.nii → S013_t2stack.nii
# Renamed: t2stack.mat → S013_t2stack.mat
# Renamed: Mu.mat → S013_Mu.mat
# Renamed: t2bet_norm.nii → S013_t2bet_norm.nii
# Renamed: t2bet.nii → G058_t2bet.nii
# Renamed: stiff_prob.mat → G058_stiff_prob.mat
# Renamed: mask.mat → G058_mask.mat
# Renamed: t2stack.nii → G058_t2stack.nii
# Renamed: t2stack.mat → G058_t2stack.mat
# Renamed: Mu.mat → G058_Mu.mat
# Renamed: t2bet_norm.nii → G058_t2bet_norm.nii
# Renamed: t2bet.nii → G054_t2bet.nii
# Renamed: stiff_prob.mat → G054_stiff_prob.mat
# Renamed: mask.mat → G054_mask.mat
# Renamed: t2stack.nii → G054_t2stack.nii
# Renamed: t2stack.mat → G054_t2stack.mat
# Renamed: Mu.mat → G054_Mu.mat
# Renamed: t2bet_norm.nii → G054_t2bet_norm.nii
# Renamed: t2bet.nii → S036_t2bet.nii
# Renamed: stiff_prob.mat → S036_stiff_prob.mat
# Renamed: mask.mat → S036_mask.mat
# Renamed: t2stack.nii → S036_t2stack.nii
# Renamed: t2stack.mat → S036_t2stack.mat
# Renamed: Mu.mat → S036_Mu.mat
# Renamed: t2bet_norm.nii → S036_t2bet_norm.nii
# Renamed: t2bet.nii → G010_t2bet.nii
# Renamed: stiff_prob.mat → G010_stiff_prob.mat
# Renamed: mask.mat → G010_mask.mat
# Renamed: t2stack.nii → G010_t2stack.nii
# Renamed: t2stack.mat → G010_t2stack.mat
# Renamed: Mu.mat → G010_Mu.mat
# Renamed: t2bet_norm.nii → G010_t2bet_norm.nii
# Renamed: t2bet.nii → G040_t2bet.nii
# Renamed: stiff_prob.mat → G040_stiff_prob.mat
# Renamed: mask.mat → G040_mask.mat
# Renamed: t2stack.nii → G040_t2stack.nii
# Renamed: t2stack.mat → G040_t2stack.mat
# Renamed: Mu.mat → G040_Mu.mat
# Renamed: t2bet_norm.nii → G040_t2bet_norm.nii
# Renamed: t2bet.nii → S006_t2bet.nii
# Renamed: stiff_prob.mat → S006_stiff_prob.mat
# Renamed: mask.mat → S006_mask.mat
# Renamed: t2stack.nii → S006_t2stack.nii
# Renamed: t2stack.mat → S006_t2stack.mat
# Renamed: Mu.mat → S006_Mu.mat
# Renamed: t2bet_norm.nii → S006_t2bet_norm.nii
# Renamed: t2bet.nii → G048_t2bet.nii
# Renamed: stiff_prob.mat → G048_stiff_prob.mat
# Renamed: mask.mat → G048_mask.mat
# Renamed: t2stack.nii → G048_t2stack.nii
# Renamed: t2stack.mat → G048_t2stack.mat
# Renamed: Mu.mat → G048_Mu.mat
# Renamed: t2bet_norm.nii → G048_t2bet_norm.nii
# Renamed: t2bet.nii → S071_t2bet.nii
# Renamed: stiff_prob.mat → S071_stiff_prob.mat
# Renamed: mask.mat → S071_mask.mat
# Renamed: t2stack.nii → S071_t2stack.nii
# Renamed: t2stack.mat → S071_t2stack.mat
# Renamed: Mu.mat → S071_Mu.mat
# Renamed: t2bet_norm.nii → S071_t2bet_norm.nii
# Renamed: t2bet.nii → S039_t2bet.nii
# Renamed: stiff_prob.mat → S039_stiff_prob.mat
# Renamed: mask.mat → S039_mask.mat
# Renamed: t2stack.nii → S039_t2stack.nii
# Renamed: t2stack.mat → S039_t2stack.mat
# Renamed: Mu.mat → S039_Mu.mat
# Renamed: t2bet_norm.nii → S039_t2bet_norm.nii
# Renamed: t2bet.nii → G024_t2bet.nii
# Renamed: stiff_prob.mat → G024_stiff_prob.mat
# Renamed: mask.mat → G024_mask.mat
# Renamed: t2stack.nii → G024_t2stack.nii
# Renamed: t2stack.mat → G024_t2stack.mat
# Renamed: Mu.mat → G024_Mu.mat
# Renamed: t2bet_norm.nii → G024_t2bet_norm.nii
# Renamed: t2bet.nii → G002_t2bet.nii
# Renamed: stiff_prob.mat → G002_stiff_prob.mat
# Renamed: mask.mat → G002_mask.mat
# Renamed: t2stack.nii → G002_t2stack.nii
# Renamed: t2stack.mat → G002_t2stack.mat
# Renamed: Mu.mat → G002_Mu.mat
# Renamed: t2bet_norm.nii → G002_t2bet_norm.nii
# Renamed: t2bet.nii → S053_t2bet.nii
# Renamed: stiff_prob.mat → S053_stiff_prob.mat
# Renamed: mask.mat → S053_mask.mat
# Renamed: t2stack.nii → S053_t2stack.nii
# Renamed: t2stack.mat → S053_t2stack.mat
# Renamed: Mu.mat → S053_Mu.mat
# Renamed: t2bet_norm.nii → S053_t2bet_norm.nii
# Renamed: t2bet.nii → S050_t2bet.nii
# Renamed: stiff_prob.mat → S050_stiff_prob.mat
# Renamed: mask.mat → S050_mask.mat
# Renamed: t2stack.nii → S050_t2stack.nii
# Renamed: t2stack.mat → S050_t2stack.mat
# Renamed: Mu.mat → S050_Mu.mat
# Renamed: t2bet_norm.nii → S050_t2bet_norm.nii
# Renamed: t2bet.nii → G016_t2bet.nii
# Renamed: stiff_prob.mat → G016_stiff_prob.mat
# Renamed: mask.mat → G016_mask.mat
# Renamed: t2stack.nii → G016_t2stack.nii
# Renamed: t2stack.mat → G016_t2stack.mat
# Renamed: Mu.mat → G016_Mu.mat
# Renamed: t2bet_norm.nii → G016_t2bet_norm.nii
# Renamed: t2bet.nii → S034_t2bet.nii
# Renamed: stiff_prob.mat → S034_stiff_prob.mat
# Renamed: mask.mat → S034_mask.mat
# Renamed: t2stack.nii → S034_t2stack.nii
# Renamed: t2stack.mat → S034_t2stack.mat
# Renamed: Mu.mat → S034_Mu.mat
# Renamed: t2bet_norm.nii → S034_t2bet_norm.nii
# Renamed: t2bet.nii → S021_t2bet.nii
# Renamed: stiff_prob.mat → S021_stiff_prob.mat
# Renamed: mask.mat → S021_mask.mat
# Renamed: t2stack.nii → S021_t2stack.nii
# Renamed: t2stack.mat → S021_t2stack.mat
# Renamed: Mu.mat → S021_Mu.mat
# Renamed: t2bet_norm.nii → S021_t2bet_norm.nii
# Renamed: t2bet.nii → S056_t2bet.nii
# Renamed: stiff_prob.mat → S056_stiff_prob.mat
# Renamed: mask.mat → S056_mask.mat
# Renamed: t2stack.nii → S056_t2stack.nii
# Renamed: t2stack.mat → S056_t2stack.mat
# Renamed: Mu.mat → S056_Mu.mat
# Renamed: t2bet_norm.nii → S056_t2bet_norm.nii
# Renamed: t2bet.nii → G042_t2bet.nii
# Renamed: stiff_prob.mat → G042_stiff_prob.mat
# Renamed: mask.mat → G042_mask.mat
# Renamed: t2stack.nii → G042_t2stack.nii
# Renamed: t2stack.mat → G042_t2stack.mat
# Renamed: Mu.mat → G042_Mu.mat
# Renamed: t2bet_norm.nii → G042_t2bet_norm.nii
# Renamed: t2bet.nii → S026_t2bet.nii
# Renamed: stiff_prob.mat → S026_stiff_prob.mat
# Renamed: mask.mat → S026_mask.mat
# Renamed: t2stack.nii → S026_t2stack.nii
# Renamed: t2stack.mat → S026_t2stack.mat
# Renamed: Mu.mat → S026_Mu.mat
# Renamed: t2bet_norm.nii → S026_t2bet_norm.nii
# Renamed: t2bet.nii → G045_t2bet.nii
# Renamed: stiff_prob.mat → G045_stiff_prob.mat
# Renamed: mask.mat → G045_mask.mat
# Renamed: t2stack.nii → G045_t2stack.nii
# Renamed: t2stack.mat → G045_t2stack.mat
# Renamed: Mu.mat → G045_Mu.mat
# Renamed: t2bet_norm.nii → G045_t2bet_norm.nii
# Renamed: t2bet.nii → S061_t2bet.nii
# Renamed: stiff_prob.mat → S061_stiff_prob.mat
# Renamed: mask.mat → S061_mask.mat
# Renamed: t2stack.nii → S061_t2stack.nii
# Renamed: t2stack.mat → S061_t2stack.mat
# Renamed: Mu.mat → S061_Mu.mat
# Renamed: t2bet_norm.nii → S061_t2bet_norm.nii
# Renamed: t2bet.nii → S010_t2bet.nii
# Renamed: stiff_prob.mat → S010_stiff_prob.mat
# Renamed: mask.mat → S010_mask.mat
# Renamed: t2stack.nii → S010_t2stack.nii
# Renamed: t2stack.mat → S010_t2stack.mat
# Renamed: Mu.mat → S010_Mu.mat
# Renamed: t2bet_norm.nii → S010_t2bet_norm.nii
# Renamed: t2bet.nii → G052_t2bet.nii
# Renamed: stiff_prob.mat → G052_stiff_prob.mat
# Renamed: mask.mat → G052_mask.mat
# Renamed: t2stack.nii → G052_t2stack.nii
# Renamed: t2stack.mat → G052_t2stack.mat
# Renamed: Mu.mat → G052_Mu.mat
# Renamed: t2bet_norm.nii → G052_t2bet_norm.nii
# Renamed: t2bet.nii → G008_t2bet.nii
# Renamed: stiff_prob.mat → G008_stiff_prob.mat
# Renamed: mask.mat → G008_mask.mat
# Renamed: .DS_Store → G008_.DS_Store
# Renamed: t2stack.nii → G008_t2stack.nii
# Renamed: toast_pipe_data_prep.m → G008_toast_pipe_data_prep.m
# Renamed: t2stack.mat → G008_t2stack.mat
# Renamed: Mu.mat → G008_Mu.mat
# Renamed: t2bet_norm.nii → G008_t2bet_norm.nii
# Renamed: t2bet.nii → S054_t2bet.nii
# Renamed: stiff_prob.mat → S054_stiff_prob.mat
# Renamed: mask.mat → S054_mask.mat
# Renamed: t2stack.nii → S054_t2stack.nii
# Renamed: t2stack.mat → S054_t2stack.mat
# Renamed: Mu.mat → S054_Mu.mat
# Renamed: t2bet_norm.nii → S054_t2bet_norm.nii
# Renamed: t2bet.nii → S065_t2bet.nii
# Renamed: stiff_prob.mat → S065_stiff_prob.mat
# Renamed: mask.mat → S065_mask.mat
# Renamed: t2stack.nii → S065_t2stack.nii
# Renamed: t2stack.mat → S065_t2stack.mat
# Renamed: Mu.mat → S065_Mu.mat
# Renamed: t2bet_norm.nii → S065_t2bet_norm.nii
# Renamed: t2bet.nii → S064_t2bet.nii
# Renamed: stiff_prob.mat → S064_stiff_prob.mat
# Renamed: mask.mat → S064_mask.mat
# Renamed: t2stack.nii → S064_t2stack.nii
# Renamed: t2stack.mat → S064_t2stack.mat
# Renamed: Mu.mat → S064_Mu.mat
# Renamed: t2bet_norm.nii → S064_t2bet_norm.nii
# Renamed: t2bet.nii → G036_t2bet.nii
# Renamed: stiff_prob.mat → G036_stiff_prob.mat
# Renamed: mask.mat → G036_mask.mat
# Renamed: t2stack.nii → G036_t2stack.nii
# Renamed: t2stack.mat → G036_t2stack.mat
# Renamed: Mu.mat → G036_Mu.mat
# Renamed: t2bet_norm.nii → G036_t2bet_norm.nii
# Renamed: t2bet.nii → S022_t2bet.nii
# Renamed: stiff_prob.mat → S022_stiff_prob.mat
# Renamed: mask.mat → S022_mask.mat
# Renamed: t2stack.nii → S022_t2stack.nii
# Renamed: t2stack.mat → S022_t2stack.mat
# Renamed: Mu.mat → S022_Mu.mat
# Renamed: t2bet_norm.nii → S022_t2bet_norm.nii
# Renamed: t2bet.nii → G023_t2bet.nii
# Renamed: stiff_prob.mat → G023_stiff_prob.mat
# Renamed: mask.mat → G023_mask.mat
# Renamed: t2mask_final.mat → G023_t2mask_final.mat
# Renamed: t2stack.nii → G023_t2stack.nii
# Renamed: t2stack.mat → G023_t2stack.mat
# Renamed: Mu.mat → G023_Mu.mat
# Renamed: t2bet_norm.nii → G023_t2bet_norm.nii
# Renamed: t2bet.nii → G061_t2bet.nii
# Renamed: stiff_prob.mat → G061_stiff_prob.mat
# Renamed: mask.mat → G061_mask.mat
# Renamed: t2stack.nii → G061_t2stack.nii
# Renamed: t2stack.mat → G061_t2stack.mat
# Renamed: Mu.mat → G061_Mu.mat
# Renamed: t2bet_norm.nii → G061_t2bet_norm.nii
# Renamed: t2bet.nii → S027_t2bet.nii
# Renamed: stiff_prob.mat → S027_stiff_prob.mat
# Renamed: mask.mat → S027_mask.mat
# Renamed: t2stack.nii → S027_t2stack.nii
# Renamed: t2stack.mat → S027_t2stack.mat
# Renamed: Mu.mat → S027_Mu.mat
# Renamed: t2bet_norm.nii → S027_t2bet_norm.nii
# Renamed: t2bet.nii → G026_t2bet.nii
# Renamed: stiff_prob.mat → G026_stiff_prob.mat
# Renamed: mask.mat → G026_mask.mat
# Renamed: t2stack.nii → G026_t2stack.nii
# Renamed: t2stack.mat → G026_t2stack.mat
# Renamed: Mu.mat → G026_Mu.mat
# Renamed: t2bet_norm.nii → G026_t2bet_norm.nii
# Renamed: t2bet.nii → G017_t2bet.nii
# Renamed: stiff_prob.mat → G017_stiff_prob.mat
# Renamed: mask.mat → G017_mask.mat
# Renamed: t2stack.nii → G017_t2stack.nii
# Renamed: t2stack.mat → G017_t2stack.mat
# Renamed: Mu.mat → G017_Mu.mat
# Renamed: t2bet_norm.nii → G017_t2bet_norm.nii
# Renamed: t2bet.nii → S028_t2bet.nii
# Renamed: stiff_prob.mat → S028_stiff_prob.mat
# Renamed: mask.mat → S028_mask.mat
# Renamed: t2stack.nii → S028_t2stack.nii
# Renamed: t2stack.mat → S028_t2stack.mat
# Renamed: Mu.mat → S028_Mu.mat
# Renamed: t2bet_norm.nii → S028_t2bet_norm.nii
# Renamed: t2bet.nii → G043_t2bet.nii
# Renamed: stiff_prob.mat → G043_stiff_prob.mat
# Renamed: mask.mat → G043_mask.mat
# Renamed: t2stack.nii → G043_t2stack.nii
# Renamed: t2stack.mat → G043_t2stack.mat
# Renamed: Mu.mat → G043_Mu.mat
# Renamed: t2bet_norm.nii → G043_t2bet_norm.nii
# Renamed: t2bet.nii → S020_t2bet.nii
# Renamed: stiff_prob.mat → S020_stiff_prob.mat
# Renamed: mask.mat → S020_mask.mat
# Renamed: t2stack.nii → S020_t2stack.nii
# Renamed: t2stack.mat → S020_t2stack.mat
# Renamed: Mu.mat → S020_Mu.mat
# Renamed: t2bet_norm.nii → S020_t2bet_norm.nii
# Renamed: t2bet.nii → S014_t2bet.nii
# Renamed: stiff_prob.mat → S014_stiff_prob.mat
# Renamed: mask.mat → S014_mask.mat
# Renamed: t2stack.nii → S014_t2stack.nii
# Renamed: t2stack.mat → S014_t2stack.mat
# Renamed: Mu.mat → S014_Mu.mat
# Renamed: t2bet_norm.nii → S014_t2bet_norm.nii
# Renamed: t2bet.nii → G038_t2bet.nii
# Renamed: stiff_prob.mat → G038_stiff_prob.mat
# Renamed: mask.mat → G038_mask.mat
# Renamed: t2stack.nii → G038_t2stack.nii
# Renamed: t2stack.mat → G038_t2stack.mat
# Renamed: Mu.mat → G038_Mu.mat
# Renamed: t2bet_norm.nii → G038_t2bet_norm.nii
# Renamed: t2bet.nii → S038_t2bet.nii
# Renamed: stiff_prob.mat → S038_stiff_prob.mat
# Renamed: mask.mat → S038_mask.mat
# Renamed: t2stack.nii → S038_t2stack.nii
# Renamed: t2stack.mat → S038_t2stack.mat
# Renamed: Mu.mat → S038_Mu.mat
# Renamed: t2bet_norm.nii → S038_t2bet_norm.nii
# Renamed: t2bet.nii → S037_t2bet.nii
# Renamed: stiff_prob.mat → S037_stiff_prob.mat
# Renamed: mask.mat → S037_mask.mat
# Renamed: t2stack.nii → S037_t2stack.nii
# Renamed: t2stack.mat → S037_t2stack.mat
# Renamed: Mu.mat → S037_Mu.mat
# Renamed: t2bet_norm.nii → S037_t2bet_norm.nii
# Renamed: t2bet.nii → S047_t2bet.nii
# Renamed: stiff_prob.mat → S047_stiff_prob.mat
# Renamed: mask.mat → S047_mask.mat
# Renamed: t2stack.nii → S047_t2stack.nii
# Renamed: t2stack.mat → S047_t2stack.mat
# Renamed: Mu.mat → S047_Mu.mat
# Renamed: t2bet_norm.nii → S047_t2bet_norm.nii
# Renamed: t2bet.nii → S063_t2bet.nii
# Renamed: stiff_prob.mat → S063_stiff_prob.mat
# Renamed: mask.mat → S063_mask.mat
# Renamed: t2stack.nii → S063_t2stack.nii
# Renamed: t2stack.mat → S063_t2stack.mat
# Renamed: Mu.mat → S063_Mu.mat
# Renamed: t2bet_norm.nii → S063_t2bet_norm.nii
# Renamed: t2bet.nii → G019_t2bet.nii
# Renamed: stiff_prob.mat → G019_stiff_prob.mat
# Renamed: mask.mat → G019_mask.mat
# Renamed: t2mask_final.mat → G019_t2mask_final.mat
# Renamed: t2stack.nii → G019_t2stack.nii
# Renamed: t2stack.mat → G019_t2stack.mat
# Renamed: Mu.mat → G019_Mu.mat
# Renamed: t2bet_norm.nii → G019_t2bet_norm.nii
# Renamed: t2bet.nii → G059_t2bet.nii
# Renamed: stiff_prob.mat → G059_stiff_prob.mat
# Renamed: mask.mat → G059_mask.mat
# Renamed: t2stack.nii → G059_t2stack.nii
# Renamed: t2stack.mat → G059_t2stack.mat
# Renamed: Mu.mat → G059_Mu.mat
# Renamed: t2bet_norm.nii → G059_t2bet_norm.nii
# Renamed: t2bet.nii → G032_t2bet.nii
# Renamed: stiff_prob.mat → G032_stiff_prob.mat
# Renamed: mask.mat → G032_mask.mat
# Renamed: t2stack.nii → G032_t2stack.nii
# Renamed: t2stack.mat → G032_t2stack.mat
# Renamed: Mu.mat → G032_Mu.mat
# Renamed: t2bet_norm.nii → G032_t2bet_norm.nii
# Renamed: t2bet.nii → S052_t2bet.nii
# Renamed: stiff_prob.mat → S052_stiff_prob.mat
# Renamed: mask.mat → S052_mask.mat
# Renamed: t2stack.nii → S052_t2stack.nii
# Renamed: t2stack.mat → S052_t2stack.mat
# Renamed: Mu.mat → S052_Mu.mat
# Renamed: t2bet_norm.nii → S052_t2bet_norm.nii
# Renamed: t2bet.nii → G018_t2bet.nii
# Renamed: stiff_prob.mat → G018_stiff_prob.mat
# Renamed: mask.mat → G018_mask.mat
# Renamed: t2stack.nii → G018_t2stack.nii
# Renamed: t2stack.mat → G018_t2stack.mat
# Renamed: Mu.mat → G018_Mu.mat
# Renamed: t2bet_norm.nii → G018_t2bet_norm.nii
# Renamed: t2bet.nii → S025_t2bet.nii
# Renamed: stiff_prob.mat → S025_stiff_prob.mat
# Renamed: mask.mat → S025_mask.mat
# Renamed: t2stack.nii → S025_t2stack.nii
# Renamed: t2stack.mat → S025_t2stack.mat
# Renamed: Mu.mat → S025_Mu.mat
# Renamed: t2bet_norm.nii → S025_t2bet_norm.nii
# Renamed: t2bet.nii → S057_t2bet.nii
# Renamed: stiff_prob.mat → S057_stiff_prob.mat
# Renamed: mask.mat → S057_mask.mat
# Renamed: t2stack.nii → S057_t2stack.nii
# Renamed: t2stack.mat → S057_t2stack.mat
# Renamed: Mu.mat → S057_Mu.mat
# Renamed: t2bet_norm.nii → S057_t2bet_norm.nii
# Renamed: t2bet.nii → S066_t2bet.nii
# Renamed: stiff_prob.mat → S066_stiff_prob.mat
# Renamed: mask.mat → S066_mask.mat
# Renamed: t2stack.nii → S066_t2stack.nii
# Renamed: t2stack.mat → S066_t2stack.mat
# Renamed: Mu.mat → S066_Mu.mat
# Renamed: t2bet_norm.nii → S066_t2bet_norm.nii
# Renamed: t2bet.nii → G056_t2bet.nii
# Renamed: stiff_prob.mat → G056_stiff_prob.mat
# Renamed: mask.mat → G056_mask.mat
# Renamed: t2stack.nii → G056_t2stack.nii
# Renamed: t2stack.mat → G056_t2stack.mat
# Renamed: Mu.mat → G056_Mu.mat
# Renamed: t2bet_norm.nii → G056_t2bet_norm.nii
# Renamed: t2bet.nii → G027_t2bet.nii
# Renamed: stiff_prob.mat → G027_stiff_prob.mat
# Renamed: mask.mat → G027_mask.mat
# Renamed: t2stack.nii → G027_t2stack.nii
# Renamed: t2stack.mat → G027_t2stack.mat
# Renamed: Mu.mat → G027_Mu.mat
# Renamed: t2bet_norm.nii → G027_t2bet_norm.nii

# %%
! pwd
# Out:
# /home/smooi/Desktop/toast

# %%
from pathlib import Path
import shutil

root_dir = Path("/home/smooi/Desktop/toast/data/toast_pipe_data")
mask_dir = root_dir / "mask"
t2stack_dir = root_dir / "t2stack"

# Ensure destination directories exist
mask_dir.mkdir(exist_ok=True)
t2stack_dir.mkdir(exist_ok=True)

# Traverse all subfolders
for subject_folder in root_dir.iterdir():
    if subject_folder.is_dir() and subject_folder.name not in ["mask", "t2stack", "empty_data"]:
        # Find files matching *_mask.mat and *_t2stack.nii
        for file in subject_folder.glob("*_mask.mat"):
            dest = mask_dir / file.name
            shutil.copy2(file, dest)
            print(f"Copied: {file} → {dest}")

        for file in subject_folder.glob("*_t2stack.nii"):
            dest = t2stack_dir / file.name
            shutil.copy2(file, dest)
            print(f"Copied: {file} → {dest}")
# Out:
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G041/G041_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G041_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G041/G041_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G041_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G053/G053_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G053_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G053/G053_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G053_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G014/G014_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G014_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G014/G014_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G014_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G047/G047_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G047_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G047/G047_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G047_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S023/S023_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S023_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S023/S023_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S023_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S043/S043_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S043_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S043/S043_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S043_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S030/S030_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S030_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S030/S030_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S030_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G011/G011_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G011_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G011/G011_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G011_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S015/S015_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S015_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S015/S015_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S015_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G037/G037_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G037_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G037/G037_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G037_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S070/S070_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S070_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S070/S070_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S070_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S011/S011_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S011_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S011/S011_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S011_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S044/S044_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S044_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S044/S044_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S044_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G021/G021_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G021_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G021/G021_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G021_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S045/S045_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S045_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S045/S045_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S045_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G029/G029_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G029_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G029/G029_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G029_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S031/S031_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S031_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S031/S031_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S031_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G028/G028_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G028_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G028/G028_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G028_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G044/G044_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G044_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G044/G044_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G044_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G022/G022_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G022_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G022/G022_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G022_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S042/S042_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S042_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S042/S042_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S042_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G046/G046_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G046_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G046/G046_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G046_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G007/G007_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G007_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G007/G007_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G007_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G025/G025_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G025_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G025/G025_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G025_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G060/G060_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G060_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G060/G060_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G060_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S012/S012_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S012_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S012/S012_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S012_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S018/S018_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S018_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S018/S018_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S018_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G035/G035_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G035_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G035/G035_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G035_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S055/S055_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S055_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S055/S055_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S055_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G033/G033_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G033_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G033/G033_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G033_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G051/G051_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G051_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G051/G051_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G051_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S067/S067_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S067_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S067/S067_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S067_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G015/G015_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G015_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G015/G015_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G015_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G049/G049_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G049_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G049/G049_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G049_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G030/G030_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G030_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G030/G030_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G030_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S032/S032_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S032_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S032/S032_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S032_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G050/G050_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G050_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G050/G050_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G050_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G012/G012_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G012_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G012/G012_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G012_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G001/G001_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G001_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G001/G001_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G001_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S049/S049_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S049_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S049/S049_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S049_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S068/S068_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S068_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S068/S068_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S068_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S046/S046_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S046_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S046/S046_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S046_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G031/G031_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G031_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G031/G031_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G031_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G055/G055_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G055_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G055/G055_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G055_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G006/G006_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G006_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G006/G006_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G006_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G034/G034_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G034_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G034/G034_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G034_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S051/S051_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S051_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S051/S051_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S051_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G004/G004_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G004_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G004/G004_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G004_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S040/S040_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S040_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S040/S040_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S040_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S008/S008_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S008_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S008/S008_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S008_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S035/S035_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S035_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S035/S035_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S035_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S062/S062_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S062_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S062/S062_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S062_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G039/G039_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G039_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G039/G039_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G039_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S041/S041_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S041_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S041/S041_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S041_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S029/S029_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S029_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S029/S029_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S029_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G005/G005_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G005_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G005/G005_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G005_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S033/S033_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S033_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S033/S033_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S033_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G013/G013_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G013_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G013/G013_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G013_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G020/G020_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G020_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G020/G020_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G020_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G003/G003_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G003_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G003/G003_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G003_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S007/S007_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S007_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S007/S007_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S007_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S059/S059_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S059_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S059/S059_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S059_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S001/S001_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S001_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S001/S001_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S001_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G009/G009_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G009_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G009/G009_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G009_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G062/G062_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G062_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G062/G062_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G062_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S002/S002_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S002_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S002/S002_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S002_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S003/S003_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S003_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S003/S003_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S003_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G057/G057_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G057_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G057/G057_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G057_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S019/S019_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S019_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S019/S019_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S019_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S017/S017_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S017_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S017/S017_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S017_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S024/S024_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S024_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S024/S024_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S024_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S058/S058_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S058_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S058/S058_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S058_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S005/S005_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S005_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S005/S005_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S005_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S016/S016_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S016_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S016/S016_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S016_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G063/G063_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G063_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G063/G063_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G063_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S072/S072_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S072_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S072/S072_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S072_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S060/S060_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S060_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S060/S060_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S060_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S004/S004_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S004_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S004/S004_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S004_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S069/S069_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S069_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S069/S069_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S069_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S009/S009_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S009_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S009/S009_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S009_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S048/S048_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S048_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S048/S048_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S048_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S013/S013_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S013_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S013/S013_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S013_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G058/G058_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G058_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G058/G058_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G058_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G054/G054_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G054_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G054/G054_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G054_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S036/S036_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S036_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S036/S036_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S036_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G010/G010_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G010_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G010/G010_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G010_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G040/G040_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G040_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G040/G040_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G040_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S006/S006_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S006_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S006/S006_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S006_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G048/G048_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G048_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G048/G048_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G048_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S071/S071_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S071_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S071/S071_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S071_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S039/S039_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S039_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S039/S039_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S039_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G024/G024_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G024_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G024/G024_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G024_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G002/G002_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G002_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G002/G002_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G002_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S053/S053_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S053_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S053/S053_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S053_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S050/S050_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S050_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S050/S050_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S050_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G016/G016_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G016_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G016/G016_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G016_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S034/S034_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S034_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S034/S034_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S034_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S021/S021_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S021_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S021/S021_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S021_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S056/S056_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S056_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S056/S056_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S056_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G042/G042_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G042_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G042/G042_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G042_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S026/S026_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S026_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S026/S026_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S026_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G045/G045_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G045_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G045/G045_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G045_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S061/S061_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S061_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S061/S061_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S061_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S010/S010_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S010_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S010/S010_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S010_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G052/G052_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G052_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G052/G052_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G052_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G008/G008_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G008_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G008/G008_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G008_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S054/S054_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S054_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S054/S054_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S054_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S065/S065_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S065_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S065/S065_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S065_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S064/S064_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S064_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S064/S064_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S064_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G036/G036_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G036_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G036/G036_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G036_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S022/S022_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S022_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S022/S022_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S022_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G023/G023_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G023_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G023/G023_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G023_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G061/G061_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G061_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G061/G061_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G061_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S027/S027_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S027_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S027/S027_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S027_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G026/G026_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G026_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G026/G026_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G026_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G017/G017_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G017_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G017/G017_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G017_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S028/S028_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S028_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S028/S028_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S028_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G043/G043_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G043_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G043/G043_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G043_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S020/S020_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S020_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S020/S020_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S020_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S014/S014_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S014_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S014/S014_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S014_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G038/G038_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G038_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G038/G038_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G038_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S038/S038_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S038_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S038/S038_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S038_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S037/S037_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S037_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S037/S037_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S037_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S047/S047_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S047_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S047/S047_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S047_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S063/S063_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S063_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S063/S063_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S063_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G019/G019_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G019_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G019/G019_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G019_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G059/G059_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G059_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G059/G059_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G059_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G032/G032_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G032_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G032/G032_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G032_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S052/S052_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S052_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S052/S052_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S052_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G018/G018_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G018_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G018/G018_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G018_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S025/S025_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S025_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S025/S025_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S025_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S057/S057_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S057_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S057/S057_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S057_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S066/S066_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/S066_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/S066/S066_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/S066_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G056/G056_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G056_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G056/G056_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G056_t2stack.nii
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G027/G027_mask.mat → /home/smooi/Desktop/toast/data/toast_pipe_data/mask/G027_mask.mat
# Copied: /home/smooi/Desktop/toast/data/toast_pipe_data/G027/G027_t2stack.nii → /home/smooi/Desktop/toast/data/toast_pipe_data/t2stack/G027_t2stack.nii

# %%
# Count the number of files in mask and t2stack directories
mask_count = len(list(mask_dir.glob("*")))
t2stack_count = len(list(t2stack_dir.glob("*")))
print(f"Number of files in mask directory: {mask_count}")
print(f"Number of files in t2stack directory: {t2stack_count}")
# Out:
# Number of files in mask directory: 135
# Number of files in t2stack directory: 135
